# %% [markdown]
# # Guide de visualisation avec Pandas et autres
#
# cf :
# Pandas doc Styling https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html
#
# Tuto : https://towardsdatascience.com/complete-guide-to-data-visualization-with-python-2dd74df12b5e

# %%
import pandas as pd
df_temporal = pd.read_csv("./datasets/popularidad/temporal.csv")

# %%
from IPython.display import display_html
def display_side_by_side(*args):
    """
    display dataframes in row
    """
    html_str=''
    for df in args:
        type(df)
        if type(df) == pd.core.frame.DataFrame :
            html_str+=df.to_html()
        elif type (df) == pd.io.formats.style.Styler :
            html_str+=df.render()
    display_html(html_str.replace('table','table style="display:inline"'),raw=True)

# %%
def exhaustiveDescribe(p_dataframe) : 
    """
    @parameter = Dataframe
    Display info, sum of nan, head6, shape & describe from a data frame in row 
    using "display_side_by_side" function from IPython.display import display_html
    """
    pd.set_option('display.max_rows', p_dataframe.shape[0])
    pd.set_option('display.max_columns', p_dataframe.shape[1])
    pd.set_option('display.width', 1000)
    
    # Vars (it's uselese to make var here, but I'm trying to change the style, but it doesn't work)
    df_shape = pd.DataFrame(df_temporal.shape, index=['Lines', 'Columns'], columns=["Shape"])
    df_head = p_dataframe.head(6)
    df_info = pd.DataFrame(p_dataframe.info())
    df_nan = pd.DataFrame(p_dataframe.isna().sum(), columns=["Number of NaN"])
    df_describe = pd.DataFrame(p_dataframe.describe())
    
    # Display
    display_side_by_side(
        df_shape,
        df_head,
        df_info,
        df_nan,
        df_describe
                        )

# %%
exhaustiveDescribe(df_temporal)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Mes               194 non-null    object
#  1   data science      194 non-null    int64
#  2   machine learning  194 non-null    int64
#  3   deep learning     194 non-null    int64
#  4   categorical       194 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.7+ KB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-2eaf32f00483> in <module>
# ----> 1 exhaustiveDescribe(df_temporal)
#
# <ipython-input-81-7e01f63dc5ee> in exhaustiveDescribe(p_dataframe)
#      22         df_info,
#      23         df_nan,
# ---> 24         df_describe
#      25                         )
#
# <ipython-input-80-faf2a4aa1b1c> in display_side_by_side(*args)
# ...

# %%
df_style = df_temporal.style.background_gradient(cmap="YlGn")

# %%
df_style
# Out:
# <style  type="text/css" >
#     #T_d2a92e06_0109_11eb_8ac8_68f728e5ba9arow0_col1 {
#             background-color:  #fafdc8;
#             color:  #000000;
#             background-color:  #fafdc8;
#             color:  #000000;
#         }    #T_d2a92e06_0109_11eb_8ac8_68f728e5ba9arow0_col2 {
#             background-color:  #f7fcbc;
#             color:  #000000;
#             background-color:  #f7fcbc;
#             color:  #000000;
#         }    #T_d2a92e06_0109_11eb_8ac8_68f728e5ba9arow0_col3 {
#             background-color:  #fdfedb;
#             color:  #000000;
#             background-color:  #fdfedb;
#             color:  #000000;
#         }    #T_d2a92e06_0109_11eb_8ac8_68f728e5ba9arow0_col4 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#             background-color:  #004529;
#             color:  #f1f1f1;
#         }    #T_d2a92e06_0109_11eb_8ac8_68f728e5ba9arow1_col1 {
#             background-color:  #fafdc8;
# ...

# %%
df_temporal.style.bar(subset=["data science", "machine learning", "deep learning"], align="left", color="green")
# Out:
# <style  type="text/css" >
#     #T_bd567000_010b_11eb_a991_68f728e5ba9arow0_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 8.3%, transparent 8.3%);
#         }    #T_bd567000_010b_11eb_a991_68f728e5ba9arow0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 11.8%, transparent 11.8%);
#         }    #T_bd567000_010b_11eb_a991_68f728e5ba9arow0_col3 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 3.0%, transparent 3.0%);
#         }    #T_bd567000_010b_11eb_a991_68f728e5ba9arow1_col1 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,green 8.3%, transparent 8.3%);
#         }    #T_bd567000_010b_11eb_a991_68f728e5ba9arow1_col2 {
#             width:  10em;
#              height:  80%;
# ...

# %%
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "4pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

# %%
df_temporal.style.background_gradient('YlGn', axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_2106b738_0226_11eb_b781_68f728e5ba9a th {
#           font-size: 4pt;
#     }    #T_2106b738_0226_11eb_b781_68f728e5ba9a td {
#           padding: 0em 0em;
#     }    #T_2106b738_0226_11eb_b781_68f728e5ba9a th:hover {
#           font-size: 12pt;
#     }    #T_2106b738_0226_11eb_b781_68f728e5ba9a tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_2106b738_0226_11eb_b781_68f728e5ba9arow0_col0 {
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_2106b738_0226_11eb_b781_68f728e5ba9arow0_col1 {
#             background-color:  #3ca458;
#             color:  #000000;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_2106b738_0226_11eb_b781_68f728e5ba9arow0_col2 {
#             background-color:  #004529;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
# ...
